# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...
#   Created wheel for peewee: filename=peewee-3.18.1-cp312-cp312-macosx_11_0_arm64.whl size=264309 sha256=9ed8f641b46faa138452e7ea7928d8abd30911ff27de5f70ddeb31e87df4e1ce
#   Stored in directory: /Users/rachita/Library/Caches/pip/wheels/1a/57/6a/bb71346381d0d911cd4ce3026f1fa720da76707e4f01cf27dd
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. This will involve a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** Use [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) for hints and instructions (it should just be a matter of replacing certain values. Use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ### WARNING: MAKE SURE TO CHECK THE LINK ABOVE FOR THE LATEST WORKING API. "google" MAY NOT ALWAYS WORK.
# ------------
# ### We also provide pickle file in the article lecture right before the video lectures.

# %%
import yfinance as yf

data = yf.download(["BAC","C","GS","JPM","MS"], start="2006-01-01", end="2016-01-01")
data.head()
# Out:
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/1834877463.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(["BAC","C","GS","JPM","MS"], start="2006-01-01", end="2016-01-01")
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                                    High  \
# Ticker            BAC           C         GS        JPM         MS        BAC
# Date
# 2006-01-03  30.991047  321.442688  94.820503  24.093309  31.934694  31.056872
# 2006-01-04  30.661909  315.508057  93.510834  23.954258  31.956585  31.096363
# 2006-01-05  30.701420  317.073334  93.473976  24.026800  32.044212  30.826492
# 2006-01-06  30.655325  317.073334  94.798401  24.196095  32.077065  30.879135
# 2006-01-09  30.675081  315.573334  95.938881  24.589083  32.416641  30.918641
#
# Price                                                    ...       Open  \
# ...

# %%
import yfinance as yf

data = yf.download("BAC", start="2006-01-01", end="2016-01-01")
data_Citi = yf.download("C", start="2006-01-01", end="2016-01-01")

data_GS = yf.download("GS", start="2006-01-01", end="2016-01-01")
data_JPM = yf.download("JPM", start="2006-01-01", end="2016-01-01")
data_MS = yf.download("MS", start="2006-01-01", end="2016-01-01")
data_WFS = yf.download("WFS", start="2006-01-01", end="2016-01-01")
data_Citi.head()
# Out:
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/1035129219.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("BAC", start="2006-01-01", end="2016-01-01")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/1035129219.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data_Citi = yf.download("C", start="2006-01-01", end="2016-01-01")
# [*********************100%***********************]  1 of 1 completed
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/1035129219.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data_GS = yf.download("GS", start="2006-01-01", end="2016-01-01")
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
data_WFS.head()
# Out:
# Price         Close     High      Low     Open Volume
# Ticker          WFS      WFS      WFS      WFS    WFS
# Date
# 2007-01-29  13.4448  13.4448  13.4448  13.4448      0
# 2007-01-30  13.5705  14.0552  13.5705  13.5705      0
# 2007-01-31  13.5220  13.5220  13.5220  13.5220      0
# 2007-02-01  13.5705  13.6480  13.5705  13.6480    309
# 2007-02-02  13.3766  13.7644  13.3766  13.7644    516

# %%
data.columns.values

data.columns = [' - '.join(col) for col in data.columns.values]

data.head()
# Out:
#             Close - BAC  High - BAC  Low - BAC  Open - BAC  Volume - BAC
# Date
# 2006-01-03    30.991037   31.056863  30.378852   30.885713      16296700
# 2006-01-04    30.661911   31.096365  30.576336   30.938380      17757900
# 2006-01-05    30.701426   30.826497  30.490781   30.661931      14970700
# 2006-01-06    30.655329   30.879138  30.510510   30.806729      12599800
# 2006-01-09    30.675079   30.918639  30.517098   30.754073      15619400

# %%
data.head()
# Out:
# Price           Close                                                   \
# Ticker            BAC           C         GS        JPM         MS WFS
# Date
# 2006-01-03  30.991047  321.442688  94.820503  24.093309  31.934694 NaN
# 2006-01-04  30.661909  315.508057  93.510834  23.954258  31.956585 NaN
# 2006-01-05  30.701420  317.073334  93.473976  24.026800  32.044212 NaN
# 2006-01-06  30.655325  317.073334  94.798401  24.196095  32.077065 NaN
# 2006-01-09  30.675081  315.573334  95.938881  24.589083  32.416641 NaN
#
# Price            High                                    ...       Open  \
# Ticker            BAC           C         GS        JPM  ...         GS
# Date                                                     ...
# 2006-01-03  31.056872  322.029615  95.239906  24.195223  ...  93.223853
# 2006-01-04  31.096363  320.203513  94.849967  24.268650  ...  93.702139
# 2006-01-05  30.826492  318.116751  93.679995  24.069122  ...  92.708760
# ...

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %% [markdown]
# ** Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %% [markdown]
# ** Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Check the head of the bank_stocks dataframe.**

# %%
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
data.head()
# Out:
# Price           Close                                                   \
# Ticker            BAC           C         GS        JPM         MS WFS
# Date
# 2006-01-03  30.991047  321.442688  94.820503  24.093309  31.934694 NaN
# 2006-01-04  30.661909  315.508057  93.510834  23.954258  31.956585 NaN
# 2006-01-05  30.701420  317.073334  93.473976  24.026800  32.044212 NaN
# 2006-01-06  30.655325  317.073334  94.798401  24.196095  32.077065 NaN
# 2006-01-09  30.675081  315.573334  95.938881  24.589083  32.416641 NaN
#
# Price            High                                    ...       Open  \
# Ticker            BAC           C         GS        JPM  ...         GS
# Date                                                     ...
# 2006-01-03  31.056872  322.029615  95.239906  24.195223  ...  93.223853
# 2006-01-04  31.096363  320.203513  94.849967  24.268650  ...  93.702139
# 2006-01-05  30.826492  318.116751  93.679995  24.069122  ...  92.708760
# ...

# %%
data.columns
# Out:
# MultiIndex([( 'Close', 'BAC'),
#             ( 'Close',   'C'),
#             ( 'Close',  'GS'),
#             ( 'Close', 'JPM'),
#             ( 'Close',  'MS'),
#             ( 'Close', 'WFS'),
#             (  'High', 'BAC'),
#             (  'High',   'C'),
#             (  'High',  'GS'),
#             (  'High', 'JPM'),
#             (  'High',  'MS'),
#             (  'High', 'WFS'),
#             (   'Low', 'BAC'),
#             (   'Low',   'C'),
#             (   'Low',  'GS'),
#             (   'Low', 'JPM'),
#             (   'Low',  'MS'),
#             (   'Low', 'WFS'),
#             (  'Open', 'BAC'),
#             (  'Open',   'C'),
#             (  'Open',  'GS'),
#             (  'Open', 'JPM'),
#             (  'Open',  'MS'),
#             (  'Open', 'WFS'),
#             ('Volume', 'BAC'),
#             ('Volume',   'C'),
#             ('Volume',  'GS'),
#             ('Volume', 'JPM'),
#             ('Volume',  'MS'),
#             ('Volume', 'WFS')],
# ...

# %%
data.head()

# data.columns
data.xs(key = 'Close',axis= 1, level = 'Price').max()
# Out:
# Ticker
# BAC     37.478725
# C      383.228180
# GS     185.153198
# JPM     53.603737
# MS      50.061161
# WFS     13.570500
# dtype: float64

# %%
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
idx = pd.IndexSlice

df = data.loc[:, data.columns.get_level_values(0).isin(['Close', 'Open'])]

# %%
df_ret = pd.DataFrame()

# %%
set(data.columns.get_level_values(1))
# Out:
# {'BAC', 'C', 'GS', 'JPM', 'MS'}

# %%
# i = 'BAC'
for i in set(data.columns.get_level_values(1)): 
    f = df.loc[:, df.columns.get_level_values(1).isin([i])]
    f['change'] = ((f['Open']-f['Close'])/f['Close'])*100
    nm = 'change_' + i
    df_ret[nm] = f['change']
# for i in ['BAC','C','GS','JPM','MS']:
# Out:
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/2202504716.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['change'] = ((f['Open']-f['Close'])/f['Close'])*100
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/2202504716.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['change'] = ((f['Open']-f['Close'])/f['Close'])*100
# /var/folders/l3/f7hpz30s08nbzkwqz28bhvnr0000gn/T/ipykernel_68049/2202504716.py:4: SettingWithCopyWarning:
# ...

# %%
df_ret
# Out:
#             change_BAC  change_JPM  change_C  change_GS  change_MS
# Date
# 2006-01-03   -0.339855   -0.895737 -0.588353  -1.683866  -1.955073
# 2006-01-04    0.901671    0.403836  0.992149   0.204581   0.599833
# 2006-01-05   -0.128640   -0.327129 -0.370222  -0.818641   0.068366
# 2006-01-06    0.493879   -0.249881  0.534754  -1.203039   0.341473
# 2006-01-09    0.257517   -1.942457  0.433975  -1.449497  -0.946102
# ...                ...         ...       ...        ...        ...
# 2015-12-24    0.289515    0.030036 -0.436349  -0.109605   0.277094
# 2015-12-28    0.525395   -0.135577  0.362731   0.082595   0.590620
# 2015-12-29   -0.173615   -0.342930 -0.415253  -0.386853  -0.337944
# 2015-12-30    0.879774    0.675784  1.032507   0.697766   0.837730
# 2015-12-31    1.069521    0.242320  0.618357   0.516012   0.314368
#
# [2517 rows x 5 columns]

# %% [markdown]
# ** We can use pandas pct_change() method on the Close column to create a column representing this return value. Create a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
sns.set_style(style = 'whitegrid')
gh = sns.pairplot(df_ret)
gh.figure

# %% [markdown]
# * See solution for details about Citigroup behavior....

# %% [markdown]
# ** Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
df_ret.idxmin()
# Out:
# change_BAC   2009-04-21
# change_JPM   2008-09-26
# change_C     2009-02-06
# change_GS    2008-11-24
# change_MS    2008-11-24
# dtype: datetime64[ns]

# %%
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ** Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
df_ret.std()
# Out:
# change_BAC    3.006922
# change_JPM    2.303599
# change_C      3.242386
# change_GS     2.105951
# change_MS     2.937101
# dtype: float64

# %%
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Create a distplot using seaborn of thereturns for Morgan Stanley **

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_ret['change_MS'].info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Series name: change_MS
# Non-Null Count  Dtype
# --------------  -----
# 2517 non-null   float64
# dtypes: float64(1)
# memory usage: 39.3 KB

# %%
plt.clf()
# df_ret['change_MS'].plot.box()
plt.figure(figsize= (10,3))
gh1 = sns.histplot(df_ret['change_MS'],color='green', kde = True, bins = 500)
# gh1 = sns.kdeplot(df_ret['change_MS'],color='green')
gh1.figure

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
from datetime import datetime as dt

# %%
df_ret['2008-01-01':]
# Out:
#             change_BAC  change_JPM  change_C  change_GS  change_MS
# Date
# 2008-01-02    2.391512    3.272471  2.800821   3.468207   3.984296
# 2008-01-03    0.818863    1.098374  1.002428   1.991799   0.530036
# 2008-01-04    0.376415    1.172733  1.310203   0.535191   1.257604
# 2008-01-07    0.375934   -0.580556  0.283081   2.824424   2.463255
# 2008-01-08    4.608176    4.433245  4.863674   3.329814   4.849138
# ...                ...         ...       ...        ...        ...
# 2015-12-24    0.289515    0.030036 -0.436349  -0.109605   0.277094
# 2015-12-28    0.525395   -0.135577  0.362731   0.082595   0.590620
# 2015-12-29   -0.173615   -0.342930 -0.415253  -0.386853  -0.337944
# 2015-12-30    0.879774    0.675784  1.032507   0.697766   0.837730
# 2015-12-31    1.069521    0.242320  0.618357   0.516012   0.314368
#
# [2015 rows x 5 columns]

# %%
sns.distplot(df_ret.ix['2015-01-01':'2015-12-31']['MS Return'],color='green',bins=100)

# %%
plt.clf()
gh1 = sns.histplot(df_ret['2008-01-01':]['change_C'],color='green', kde = True, bins = 500)
# gh1 = sns.kdeplot(df_ret['change_MS'],color='green')
gh1.figure
# dtyear(df_ret.index)
# df_ret[

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
data.head()
ht = data.xs(key='Close',axis=1,level='Price').plot()
ht.figure

# %%
data.head()
plt.clf()
tr = data.xs(key = 'Close', level = 'Price', axis = 1)
ft = sns.lineplot(data = tr)

ft.figure

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize=(12,6))
ty = data.xs(key = 'Close', level = 'Price', axis = 1)[['BAC']].rolling(window=30).mean().plot(label='30 Day Avg')

ty.figure
# BAC['Close'].ix['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
# BAC['Close'].ix['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
# plt.legend()

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
plt.clf()
cr_mat = data.xs(key = 'Close', level = 'Price', axis = 1).corr()

gh = sns.heatmap(cr_mat)
gh.figure
# gh = sns.heatmap(cr_mat, )
# gh.figure

# %%
plt.clf()
cr_mat = data.xs(key = 'Close', level = 'Price', axis = 1).corr()

gh = sns.clustermap(cr_mat)
gh.figure
# gh = sns.heatm

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
data.xs(key = 'BAC', level = 'Ticker', axis = 1)['2015-01-01':'2016-01-01'].iplot(kind='candle')
# BAC[['Open', 'High', 'Low', 'Close']].ix['2015-01-01':'2016-01-01'].iplot(kind='candle')

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
data.xs(key = 'BAC', level = 'Ticker', axis = 1)['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,55],title='Simple Moving Averages')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# /opt/anaconda3/lib/python3.12/site-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
data.xs(key = 'BAC', level = 'Ticker', axis = 1)['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#
# /opt/anaconda3/lib/python3.12/site-packages/cufflinks/plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
