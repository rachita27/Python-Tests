# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('df1')

df.columns
df.set_index('Unnamed: 0',inplace = True)
df.head()
# Out:
#                    A         B         C         D
# Unnamed: 0
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df['A'].hist(bins = 30) ## CALLING Function
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
df2 = pd.read_csv('df2')
df2.head()

##all values of same type either all positive or all negative
df2.plot.area(alpha = 0.4)
# Out:
# <Axes: >

# %%
df.plot.line(y = 'A', figsize = (10,5), lw = 0.6, ls = '--')
# df.index
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
df.reset_index().plot.line(x = 0,y = 'A', figsize = (10,5), lw = 0.6, ls = '--')
# df.index
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
df.plot.scatter(x = 'B',y = 'A', c = 'C')
# Out:
# <Axes: xlabel='B', ylabel='A'>

# %%
df.plot.scatter(x = 'B',y = 'A', s = df['C'] * 50)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='B', ylabel='A'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.hexbin(x = 'A', y = 'B', gridsize = 20, C= 'C')
# Out:
# <Axes: xlabel='A', ylabel='B'>
